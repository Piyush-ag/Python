# %% [markdown]
# ## matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
arr_x = np.linspace(0, 10)
arr_y_1 = arr_x ** 2
arr_y_2 = arr_x ** 3
plt_1 = plt.plot(arr_x, arr_y_1, "red", label="power of 2")
plt_2 = plt.plot(arr_x, arr_y_2, "purple", label="power of 3")

plt.title("Our first plot")
plt.xlabel("x values")
plt.xlabel("y values")

# default labels
plt.legend()

# %%
arr_x = np.linspace(2, 10)
arr_y_1_1 = np.sin(arr_x)
arr_y_1_2 = np.cos(arr_x)
arr_y_1_3 = np.log(arr_x)
arr_y_2_1 = np.tan(arr_x)
arr_y_2_2 = np.sin(arr_x)
arr_y_2_3 = np.sinc(arr_x)

plt.subplot(2, 3, 1)
plt.plot(arr_x, arr_y_1_1, "navy")

plt.subplot(2, 3, 2)
plt.plot(arr_x, arr_y_1_2, "red")

plt.subplot(2, 3, 3)
plt.plot(arr_x, arr_y_1_3, "purple")

plt.subplot(2, 3, 4)
plt.plot(arr_x, arr_y_2_1, "black")

plt.subplot(2, 3, 5)
plt.plot(arr_x, arr_y_2_2, "green")

plt.subplot(2, 3, 6)
plt.plot(arr_x, arr_y_2_3, "orange")

# %%
arr_x = np.linspace(2, 10)
arr_y_1 = np.sinc(arr_x)

fig_1 = plt.figure()

axes_1 = fig_1.add_axes([0.1, 0.2, 0.4, 0.5])

axes_1.plot(arr_x, arr_y_1, "red")

axes_1.set(
    xlim=(1, 11),
    ylim=(-0.15, 0.15),
    xlabel="value of x",
    ylabel="value of y",
    title="axes title",
)
# Out:
# [(1.0, 11.0),
#  (-0.15, 0.15),
#  Text(0.5, 0, 'value of x'),
#  Text(0, 0.5, 'value of y'),
#  Text(0.5, 1.0, 'axes title')]

# %%
arr_x = np.linspace(2, 10)
arr_y_1 = np.sinc(arr_x)
arr_y_2 = np.log(arr_x)

fig_1 = plt.figure()

axes_1 = fig_1.add_axes([0.1, 0.0, 0.4, 0.25])
axes_2 = fig_1.add_axes([0.0, 0.5, 0.3, 0.4])

axes_1.plot(arr_x, arr_y_1, "red")
axes_2.plot(arr_x, arr_y_2, "purple")

axes_1.set(
    xlim=(1, 11),
    ylim=(-0.15, 0.15),
    xlabel="value of x_1",
    ylabel="value of y_1",
    title="axes_1 title",
)

axes_2.set(
    xlim=(1, 11),
    ylim=(0.5, 3),
    xlabel="value of x_2",
    ylabel="value of y_2",
    title="axes_2 title",
)

fig_1.suptitle("figure title", size=20, x=0.2, y=1.1)

fig_1.savefig(
    "save_1.png",
    bbox_inches="tight",
    pad_inches=1.5,
    transparent=True,
    facecolor="pink",
    orientation="landscape",
    dpi=300,
)

# %%
arr_x = np.linspace(2, 10)

arr_y_1 = np.cos(arr_x)
arr_y_2 = np.tan(arr_x)

fig, axes = plt.subplots(nrows=2, ncols=3)

axes[0, 0].plot(arr_x, arr_y_1, "red")
axes[1, 1].plot(arr_x, arr_y_2, "navy")

axes[0, 0].set(xlabel="x of 0,0", title="subplot at 0,0")
axes[1, 1].set(ylabel="x of 1,1", title="subplot at 1,1")

fig.suptitle("This is super title", size=20, x=0.5, y=1.05)
# Out:
# Text(0.5, 1.05, 'This is super title')

# %%
arr_x = np.linspace(2, 10)

arr_y_1 = np.cos(arr_x)
arr_y_2 = np.tan(arr_x)

fig, axes = plt.subplots(nrows=2, ncols=3)

axes[0, 0].plot(arr_x, arr_y_1, "red")
axes[1, 1].plot(arr_x, arr_y_2, "navy")

plt.tight_layout()

axes[0, 0].set(xlabel="x of 0,0", title="subplot at 0,0")
axes[1, 1].set(ylabel="x of 1,1", title="subplot at 1,1")

fig.suptitle("This is super title", size=20, x=0.5, y=1.05)
# Out:
# Text(0.5, 1.05, 'This is super title')

# %%
arr_x = np.linspace(2, 10, 100)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(5, 3), dpi=200)
plt.tight_layout(pad=2)

axes[0, 0].plot(
    arr_x, np.sin(arr_x), "red", linewidth=0.3, marker="o", markersize=1, label="r"
)
axes[0, 1].plot(arr_x, np.cos(arr_x), "black", label="b", linestyle="--")
axes[1, 0].plot(arr_x, np.tan(arr_x), "navy", label="n")
axes[1, 1].plot(arr_x, np.sinc(arr_x), "purple", linewidth=2.5, label="p")

for i, sub_p in enumerate(fig.axes):
    sub_p.set_xlabel("x_" + str(i), fontsize=4)
    sub_p.set_ylabel("y_" + str(i), fontsize=4)
    sub_p.set_title("subplot" + str(i), fontsize=7)
    sub_p.legend(loc="upper right", shadow=True, fontsize=4)

fig.suptitle("This is super title", size=12, x=0.5, y=1.05)

fig.savefig("save_me.png", bbox_inches="tight", facecolor="yellow")

# %%
import matplotlib.image as mpimg

plt.imshow(mpimg.imread("save_me.png"))

# %%
data_1 = np.random.normal(40, 5, size=300)
data_2 = np.random.random(size=4000)

fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(4, 3), dpi=150)
plt.tight_layout()

axs[0].hist(data_1, bins=20)
axs[1].hist(data_2, bins=20)
# Out:
# (array([207., 191., 184., 203., 168., 203., 199., 208., 185., 213., 208.,
#         223., 217., 181., 202., 210., 200., 210., 195., 193.]),
#  array([3.59143036e-04, 5.03410979e-02, 1.00323053e-01, 1.50305008e-01,
#         2.00286962e-01, 2.50268917e-01, 3.00250872e-01, 3.50232827e-01,
#         4.00214782e-01, 4.50196737e-01, 5.00178691e-01, 5.50160646e-01,
#         6.00142601e-01, 6.50124556e-01, 7.00106511e-01, 7.50088466e-01,
#         8.00070421e-01, 8.50052375e-01, 9.00034330e-01, 9.50016285e-01,
#         9.99998240e-01]),
#  <BarContainer object of 20 artists>)

# %%
midterm_grades = [43, 20, 50, 45, 36, 0, 50, 48]
final_grades = [52, 30, 37, 44, 60, 15, 46, 52]

fig, ax = plt.subplots(figsize=(7, 4), dpi=100)
ax.scatter(midterm_grades, final_grades, color="hotpink")

# %%
data_1 = np.random.normal(1, 50, size=300)
temp_1 = np.random.random(size=300)
temp_2 = np.random.randint(-40, 50, size=300)
data_2 = data_1 * temp_1

fig, ax = plt.subplots()
plt.tight_layout()

ax.scatter(data_1, temp_2, color="black")
ax.scatter(data_1, data_2, color="red")

# %%
fig, ax = plt.subplots()
enrollment = [5, 32, 50, 12, 1]
languages = ["Julia", "Java", "Python", "R", "Matlab"]
ax.bar(languages, enrollment)
# Out:
# <BarContainer object of 5 artists>

# %%
labels = ["Group 1", "Group 2", "Group 3", "Group 4", "Group 5"]
men_scores = [20, 34, 30, 35, 27]
women_scores = [25, 32, 34, 20, 25]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()

bar_1 = ax.bar(x - width / 2, men_scores, width, label="Men")
bar_2 = ax.bar(x + width / 2, women_scores, width, label="Women")

ax.set_ylabel("Scores")
ax.set_title("Scores by group and gender")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

# %%
students = ["Lea", "Charles", "Amanda", "Christian", "Zoe", "N", "Jessica", "Esther"]
midterm_grades = [43, 20, 50, 45, 36, 0, 50, 48]
final_grades = [52, 30, 37, 44, 60, 15, 46, 52]

fig, ax = plt.subplots(figsize=(7, 4), dpi=100)

ax.bar(students, midterm_grades, color="navy")
ax.bar(students, final_grades, bottom=midterm_grades, color="green")
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# ## seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

data_1 = np.random.random(size=200)
data_2 = np.random.normal(loc=10, scale=2, size=200)

axes = sns.scatterplot(x=data_1, y=data_2)

# %%
df = pd.read_csv("clean_search_history.csv")
df
# Out:
#        obs_date  data_science  machine_learning  deep_learning  categorical
# 0    2004-01-01            12                18              4            1
# 1    2004-02-01            12                21              2            1
# 2    2004-03-01             9                21              2            1
# 3    2004-04-01            10                16              4            1
# 4    2004-05-01             7                14              3            1
# ..          ...           ...               ...            ...          ...
# 204  2021-01-01           145               101            115            1
# 205  2021-02-01           139                98            115            0
# 206  2021-03-01           147               100            110            1
# 207  2021-04-01           150               103            112            1
# 208  2021-05-01           151                95            114            1
#
# [209 rows x 5 columns]

# %%
sns.set_style("dark")
axes = sns.barplot(data=df, x="categorical", y="data_science", palette="bright")
axes.set(xlabel="Country", xticklabels=["USA", "Canada"])
# Out:
# [Text(0.5, 0, 'Country'), [Text(0, 0, 'USA'), Text(1, 0, 'Canada')]]

# %%
sns.set_style("dark")
axes = sns.boxplot(data=df, x="categorical", y="data_science", palette="bright")
axes.set(xlabel="Country", xticklabels=["USA", "Canada"])
# Out:
# [Text(0.5, 0, 'Country'), [Text(0, 0, 'USA'), Text(1, 0, 'Canada')]]

# %%
sns.set_style("dark")
axes = sns.violinplot(data=df, x="categorical", y="data_science", palette="bright")
axes.set(xlabel="Country", xticklabels=["USA", "Canada"])
# Out:
# [Text(0.5, 0, 'Country'), [Text(0, 0, 'USA'), Text(1, 0, 'Canada')]]

# %%
sns.set_style("whitegrid")
axes = sns.histplot(data=df, x="data_science", color="navy", bins=15, palette="bright")
axes.set(xlabel="Freq", title="Histogram")
# Out:
# [Text(0.5, 0, 'Freq'), Text(0.5, 1.0, 'Histogram')]

# %%
axes = sns.distplot(df.data_science)
# Out:
# C:\Users\malamda1\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style("white")
axes = sns.jointplot(
    data=df,
    x="data_science",
    y="machine_learning",
    hue="categorical",
    hue_order=[1, 0],
    color="navy",
    palette="bright",
)

# %%
sns.set_style("darkgrid")
axes = sns.pairplot(data=df)

# %%
sns.set_style("dark")
axes = sns.lmplot(
    data=df, x="data_science", y="machine_learning", hue="categorical", palette="bright"
)

# %%
sns.set_theme()
uniform_data = np.random.random(size=(10, 10))
ax = sns.heatmap(uniform_data)

# %%
sns.set_theme()
normal_data = np.random.normal(loc=20, scale=3, size=(10, 10))
ax = sns.heatmap(normal_data, center=20)

# %%
sns.set_style("dark")
axes = sns.heatmap(df.corr(), annot=True, fmt=".2f")
